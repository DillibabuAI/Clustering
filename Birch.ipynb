# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("Mall_Customers.csv")

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
X = dataset.iloc[:,[3,4]].values

# %%
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import Birch
brc = Birch(n_clusters=None)
y_brc = brc.fit_predict(X)
y_brc
# Out:
# array([ 38,   0,  39,   1,  40,   2,  41,   3,  42,   4,  43,   5,  44,
#          6,  45,   7,  46,   8,  47,   9,  48,  10,  49,  10,  50,  11,
#         51,  12,  52,  13,  53,  14,  54,  15,  55,  16,  56,  17,  57,
#         18,  59,  19,  60,  20,  58,  21,  22,  61,  62,  62,  63,  23,
#         64,  23,  65,  66,  67,  68,  69,  70,  24,  24,  71,  25,  72,
#         25,  72,  73,  25,  73,  26,  74,  77,  27,  78,  28,  79,  78,
#         79,  75,  80,  81,  75,  76,  29,  82,  30,  83,  31,  84,  85,
#         86,  87, 140,  88,  89,  90,  87,  88,  91,  92,  93,  94,  95,
#         95,  92,  96,  97,  98,  93,  99, 100, 101,  97, 102, 103, 104,
#        105, 106, 107, 107, 141, 108,  32, 142, 109, 143,  33, 144, 110,
#        145, 110, 146, 111, 147,  34, 148, 112, 149, 113, 150,  35, 151,
#         36, 152,  37, 153, 114, 154, 115, 155, 116, 156, 117, 155, 115,
#        157, 118, 157, 119, 158, 120, 159, 121, 160, 122, 161, 123, 162,
# ...

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_brc, cmap='rainbow', edgecolor='k')
plt.title("Birch Clustering")
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.show()

# %%
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
# Evaluate clustering
silhouette_avg = silhouette_score(X, y_brc)
db_index = davies_bouldin_score(X, y_brc)
# Evaluation metrics
print("Silhouette Coefficient: {:.2f}".format(silhouette_avg))
print("Davies-Bouldin Index: {:.2f}".format(db_index))
# Out:
# Silhouette Coefficient: 0.12
# Davies-Bouldin Index: 0.11
